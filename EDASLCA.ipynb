# %%
# Required modules
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Download data
slca = 'SLCA'
us_slca = yf.Ticker(slca)
hist_data = us_slca.history(period='5y')
hist_data.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-05-01 00:00:00-04:00  16.045991  16.228989  14.033018  14.158227
# 2019-05-02 00:00:00-04:00  13.869283  13.898178  12.636458  13.301028
# 2019-05-03 00:00:00-04:00  13.541815  14.312330  13.484026  14.004124
# 2019-05-06 00:00:00-04:00  13.676654  14.090807  13.551445  13.898178
# 2019-05-07 00:00:00-04:00  13.724812  13.782601  13.108399  13.474394
#
#                             Volume  Dividends  Stock Splits
# Date
# 2019-05-01 00:00:00-04:00  3831500        0.0           0.0
# 2019-05-02 00:00:00-04:00  3120400        0.0           0.0
# 2019-05-03 00:00:00-04:00  1998300        0.0           0.0
# 2019-05-06 00:00:00-04:00  1367700        0.0           0.0
# 2019-05-07 00:00:00-04:00  1227600        0.0           0.0

# %%
# Locate April 26, 2024
hist_data.loc['2024-04-26']
# Out:
# Open            1.554000e+01
# High            1.603000e+01
# Low             1.554000e+01
# Close           1.589000e+01
# Volume          1.480660e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-04-26 00:00:00-04:00, dtype: float64

# %%
# get the income statement, balance sheet, and cash flow statement
income_statement = us_slca.financials
balance_sheet = us_slca.balance_sheet
cash_flow = us_slca.cashflow

# %%
income_statement
# Out:
#                                                       2023-12-31  \
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                          0.25
# Normalized EBITDA                                    434537000.0
# Total Unusual Items                                          0.0
# Total Unusual Items Excluding Goodwill                       0.0
# Net Income From Continuing Operation Net Minori...   146925000.0
# Reconciled Depreciation                              137259000.0
# Reconciled Cost Of Revenue                          1020627000.0
# EBITDA                                               434537000.0
# EBIT                                                 297278000.0
# Net Interest Income                                 -101709000.0
# Interest Expense                                     101709000.0
# Normalized Income                                    146925000.0
# ...

# %%
balance_sheet
# Out:
#                                                    2023-12-31    2022-12-31  \
# Treasury Shares Number                             10777871.0     9892597.0
# Ordinary Shares Number                             77192239.0    75738512.0
# Share Issued                                       77192239.0    75738512.0
# Net Debt                                          594321000.0   776148000.0
# Total Debt                                        913695000.0  1141244000.0
# ...                                                       ...           ...
# Accounts Receivable                               184866000.0   203992000.0
# Allowance For Doubtful Accounts Receivable         -5323000.0    -5691000.0
# Gross Accounts Receivable                         190189000.0   209683000.0
# Cash Cash Equivalents And Short Term Investments  245716000.0   280845000.0
# Cash And Cash Equivalents                         245716000.0   280845000.0
#
# ...

# %%
cash_flow
# Out:
#                                                  2023-12-31   2022-12-31  \
# Free Cash Flow                                  198398000.0  209154000.0
# Repurchase Of Capital Stock                             NaN          NaN
# Repayment Of Debt                              -200701000.0 -166658000.0
# Issuance Of Debt                                        NaN          0.0
# Capital Expenditure                             -65470000.0  -53562000.0
# Interest Paid Supplemental Data                  95133000.0   71235000.0
# Income Tax Paid Supplemental Data                       NaN   14809000.0
# End Cash Position                               245716000.0  280845000.0
# Beginning Cash Position                         280845000.0  239425000.0
# Changes In Cash                                 -35129000.0   41420000.0
# Financing Cash Flow                            -254276000.0 -170343000.0
# Cash Flow From Continuing Financing Activities -254276000.0 -170343000.0
# ...

# %%
# Plot the close price and the volume
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(hist_data['Close'], label='Close Price')
plt.title('Close Price')
plt.legend(loc='best')
plt.subplot(2, 1, 2)
plt.plot(hist_data['Volume'], label='Volume')
plt.title('Volume')
plt.legend(loc='best')
plt.show()

# %%
# Plot the last three years of the close price
plt.figure(figsize=(12, 8))
plt.plot(hist_data['Close'][-756:], label='Close Price')
plt.title('Close Price of SLCA (3 Yrs)')
# Add a axhline at the mean of the close price
plt.axhline(hist_data['Close'].mean(), color='red', linestyle='--', label='Mean Close Price')
plt.axhline(15.5, color='green', linestyle='--', label='Apollo Acquisition Price')
# Put a vertical line on April 26, 2024
plt.axvline(pd.Timestamp('2024-04-26'), color='black', linestyle='--', label='Apollo Acquisition Date')
plt.legend(loc='best')
plt.show()

# %%
# Set seed
import random
random.seed(42)

# Calculate the daily returns
hist_data['Daily Return'] = hist_data['Close'].pct_change()

# Get the n_obs
n_obs = hist_data['Daily Return'].count()

# Create random walk
random_walk = hist_data['Daily Return'].sample(n=n_obs, replace=True)

# Plot the random walk
sns.histplot(random_walk, kde=True)
plt.show()

# %%
# Continue the random walk from Datacamp manipulating time series data in python

# %% [markdown]
# Peers Analysis

# %%
peers = {'RPC Inc': 'RES', 'ProPetro Holding Corp': 'PUMP', 'Cactus': 'WHD', 'Core Laboratories': 'CLB', 'ChampionX Corp':'CHX', 'Patterson-UTI Energy': 'PTEN', 'Liberty Energy Inc.': 'LBRT'}

# %%
# Download data for the peers
peers_data = yf.download(list(peers.values()), start='2019-01-01', end='2024-04-26')
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
peers_data.head()
# Out:
# Price       Adj Close                                                     \
# Ticker            CHX        CLB       LBRT       PTEN   PUMP        RES
# Date
# 2019-01-02  27.204596  56.830399  12.851824   9.667268  12.62   9.883269
# 2019-01-03  27.506435  57.295212  12.632053   9.913276  13.05  10.007528
# 2019-01-04  30.232738  59.714130  13.033375  10.441743  13.33  10.083995
# 2019-01-07  31.147997  62.920395  13.176703  10.660415  13.60  10.342067
# 2019-01-08  31.849049  63.641327  12.488725  10.751533  13.57  10.083995
#
# Price                      Close                    ...   Open         \
# Ticker            WHD        CHX        CLB   LBRT  ...   PUMP    RES
# Date                                                ...
# 2019-01-02  27.098717  27.940001  59.910000  13.45  ...  12.07   9.68
# 2019-01-03  26.956245  28.250000  60.400002  13.22  ...  12.62  10.31
# 2019-01-04  28.048550  31.049999  62.950001  13.64  ...  13.36  10.58
# ...

# %%
# Get the income statement, balance sheet, and cash flow statement for the peers
income_statement_peers = {}
balance_sheet_peers = {}
cash_flow_peers = {}

for peer in peers.values():
    peer_data = yf.Ticker(peer)
    income_statement_peers[peer] = peer_data.financials
    balance_sheet_peers[peer] = peer_data.balance_sheet
    cash_flow_peers[peer] = peer_data.cashflow

# %%
# Plot the close price of the peers and slca for the past three years
plt.figure(figsize=(12, 8))
plt.plot(hist_data['Close'][-756:], label='SLCA Close Price')
for peer in peers.values():
    plt.plot(peers_data['Close'][peer][-756:], label=f'{peer} Close Price')
plt.title('Close Price of SLCA and Peers (3 Yrs)')
plt.legend(loc='best')
plt.show()

# %%
# Plot the peers and slca for the last year
plt.figure(figsize=(12, 8))
plt.plot(hist_data['Close'][-252:], label='SLCA Close Price')
for peer in peers.values():
    plt.plot(peers_data['Close'][peer][-252:], label=f'{peer} Close Price')
plt.title('Close Price of SLCA and Peers (1 Yr)')
plt.legend(loc='best')
plt.show()

# %%
income_statement_peers
# Out:
# {'RES':                                                       2023-12-31  \
#  Tax Effect Of Unusual Items                            2233216.0
#  Tax Rate For Calcs                                         0.239
#  Normalized EBITDA                                    355363000.0
#  Total Unusual Items                                    9344000.0
#  Total Unusual Items Excluding Goodwill                 9344000.0
#  Net Income From Continuing Operation Net Minori...   195113000.0
#  Reconciled Depreciation                              108123000.0
#  Reconciled Cost Of Revenue                          1197642000.0
#  EBITDA                                               364707000.0
#  EBIT                                                 256584000.0
#  Net Interest Income                                    8258000.0
#  Interest Expense                                        341000.0
#  Interest Income                                        8599000.0
# ...

# %% [markdown]
# Financial Analysis of SLCA

# %%
# Find the market cap of SLCA for the past five years
market_cap_slca = hist_data['Close'] * yf.Ticker(slca).info['sharesOutstanding']
market_cap_slca.head()
# Out:
# Date
# 2019-05-01 00:00:00-04:00    1.106250e+09
# 2019-05-02 00:00:00-04:00    1.039273e+09
# 2019-05-03 00:00:00-04:00    1.094209e+09
# 2019-05-06 00:00:00-04:00    1.085931e+09
# 2019-05-07 00:00:00-04:00    1.052819e+09
# Name: Close, dtype: float64

# %%
# Graph the market cap of SLCA
plt.figure(figsize=(12, 8))
plt.plot(market_cap_slca, label='Market Cap')
plt.title('Market Cap of SLCA')
plt.legend(loc='best')
plt.show()

# %%
# Create a function that transposes the financial statements
def transpose_financials(financials):
    return financials.T

# %%
# Transpose the income statement, balance sheet, and cash flow statement
income_statement_t = transpose_financials(income_statement)
balance_sheet_t = transpose_financials(balance_sheet)
cash_flow_t = transpose_financials(cash_flow)

# %%
income_statement_t.columns
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBITDA',
#        'EBIT', 'Net Interest Income', 'Interest Expense', 'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Total Operating Income As Reported',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Net Income', 'Minority Interests',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Other Income Expense', 'Other Non Operating Income Expenses',
# ...

# %%
# Graph the total revenue and net income of SLCA
plt.figure(figsize=(12, 8))
plt.plot(income_statement_t['Total Revenue'], label='Total Revenue')
plt.plot(income_statement_t['Net Income'], label='Net Income')
plt.title('Total Revenue and Net Income of SLCA')
plt.legend(loc='best')
plt.show()

# %%
# Calculate the growth rate of the total revenue
total_revenue = income_statement_t['Total Revenue']
total_revenue
# Out:
# 2023-12-31    1552022000.0
# 2022-12-31    1525147000.0
# 2021-12-31    1103879000.0
# 2020-12-31     845885000.0
# Name: Total Revenue, dtype: object

# %% [markdown]
# Discounted Cash Flow (DCF) Analysis

# %%
# Reorangize the total_revenue_df to have the date descending
total_revenue_df = total_revenue.reset_index()
total_revenue_df = total_revenue_df.sort_values('index', ascending=True)
total_revenue_df = total_revenue_df.set_index('index')
# Add the growth rate column
total_revenue_df['Growth Rate'] = total_revenue_df['Total Revenue'].pct_change()
total_revenue_df
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_98484\1653956209.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   total_revenue_df['Growth Rate'] = total_revenue_df['Total Revenue'].pct_change()
#            Total Revenue  Growth Rate
# index
# 2020-12-31   845885000.0          NaN
# 2021-12-31  1103879000.0     0.304999
# 2022-12-31  1525147000.0     0.381625
# 2023-12-31  1552022000.0     0.017621

# %%
# Calculate the average growth rate
average_growth_rate = total_revenue_df['Growth Rate'].mean()
# Put it in % and format to two decimal places
average_growth_rate = average_growth_rate * 100
average_growth_rate = print(f'{round(average_growth_rate, 2)}%')
average_growth_rate
# Out:
# 23.47%

# %%
# Profitability Ratios: gross profit margin, operating margin, net profit margin, return on assets, and return on equity
# Gross Profit Margin
gross_profit_margin = (income_statement_t['Total Revenue'] - income_statement_t['Cost Of Revenue']) / (income_statement_t['Total Revenue']) * 100
# Rename the column
gross_profit_margin = gross_profit_margin.rename('Gross Profit Margin')
gross_profit_margin
# Out:
# 2023-12-31    34.238883
# 2022-12-31    29.830436
# 2021-12-31    27.982777
# 2020-12-31    32.015581
# Name: Gross Profit Margin, dtype: object

# %%
import matplotlib.pyplot as plt

# Assume income_statement_t is your DataFrame and gross_profit_margin is a Series or DataFrame column

plt.figure(figsize=(12, 8))

# Create the first axis for the total revenue and cost of revenue
ax1 = plt.gca()  # Get the current Axes instance on the current figure
ax1.plot(income_statement_t['Total Revenue'], color='blue', label='Total Revenue')
ax1.plot(income_statement_t['Cost Of Revenue'], color='red', label='Cost of Revenue')

# Label the first axis
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Revenue and Cost (Dollars)')
ax1.tick_params(axis='y', colors='black')

# Create the second axis for the gross profit margin
ax2 = ax1.twinx()  # Create a twin Axes sharing the x-axis
ax2.plot(gross_profit_margin, color='green', label='Gross Profit Margin (%)')
ax2.set_ylabel('Gross Profit Margin (%)')
ax2.tick_params(axis='y', colors='green')

# Title and legend
plt.title('Total Revenue, Cost of Revenue, and Gross Profit Margin of SLCA')
# Handling legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')

plt.show()

# %%
# Operating Margin EBIT / Total Revenue
operating_margin = income_statement_t['EBIT'] / income_statement_t['Total Revenue'] * 100
# Rename the column
operating_margin = operating_margin.rename('Operating Margin')
operating_margin
# Out:
# 2023-12-31    19.154239
# 2022-12-31    11.906852
# 2021-12-31     3.087385
# 2020-12-31   -11.261815
# Name: Operating Margin, dtype: object

# %%
# Graph the ebit, total revenue, and operating margin
plt.figure(figsize=(12, 8))
# Create the first axis for the total revenue and ebit
ax1 = plt.gca()
ax1.plot(income_statement_t['Total Revenue'], color='blue', label='Total Revenue')
ax1.plot(income_statement_t['EBIT'], color='red', label='EBIT')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Revenue and EBIT (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the operating margin
ax2 = ax1.twinx()
ax2.plot(operating_margin, color='green', label='Operating Margin (%)')
ax2.set_ylabel('Operating Margin (%)')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Revenue, EBIT, and Operating Margin of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Net Profit Margin Net Income / Total Revenue
net_profit_margin = income_statement_t['Net Income'] / income_statement_t['Total Revenue'] * 100
# Rename the column
net_profit_margin = net_profit_margin.rename('Net Profit Margin')
net_profit_margin
# Out:
# 2023-12-31     9.466683
# 2022-12-31     5.125801
# 2021-12-31    -3.058397
# 2020-12-31   -13.488122
# Name: Net Profit Margin, dtype: object

# %%
# Graph the net income, total revenue, and net profit margin
plt.figure(figsize=(12, 8))
# Create the first axis for the total revenue and net income
ax1 = plt.gca()
ax1.plot(income_statement_t['Total Revenue'], color='blue', label='Total Revenue')
ax1.plot(income_statement_t['Net Income'], color='red', label='Net Income')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Revenue and Net Income (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the net profit margin
ax2 = ax1.twinx()
ax2.plot(net_profit_margin, color='green', label='Net Profit Margin (%)')
ax2.set_ylabel('Net Profit Margin (%)')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Revenue, Net Income, and Net Profit Margin of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Return on Assets Net Income / Total Assets
return_on_assets = income_statement_t['Net Income'] / balance_sheet_t['Total Assets'] * 100
# Rename the column
return_on_assets = return_on_assets.rename('Return on Assets')
return_on_assets
# Out:
# 2023-12-31    7.007798
# 2022-12-31     3.53006
# 2021-12-31    -1.52104
# 2020-12-31   -5.077734
# Name: Return on Assets, dtype: object

# %%
# Graph the net income, total assets, and return on assets
plt.figure(figsize=(12, 8))
# Create the first axis for the total assets and net income
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Total Assets'], color='blue', label='Total Assets')
ax1.plot(income_statement_t['Net Income'], color='red', label='Net Income')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Assets and Net Income (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the return on assets
ax2 = ax1.twinx()
ax2.plot(return_on_assets, color='green', label='Return on Assets (%)')
ax2.set_ylabel('Return on Assets (%)')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Assets, Net Income, and Return on Assets of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Return on Equity Net Income / Total Equity
return_on_equity = income_statement_t['Net Income'] / balance_sheet_t['Stockholders Equity'] * 100
# Rename the column
return_on_equity = return_on_equity.rename('Return on Equity')
return_on_equity
# Out:
# 2023-12-31    17.299378
# 2022-12-31     11.22114
# 2021-12-31    -5.587581
# 2020-12-31    -18.54403
# Name: Return on Equity, dtype: object

# %%
# Graph the net income, total equity, and return on equity
plt.figure(figsize=(12, 8))
# Create the first axis for the total equity and net income
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Stockholders Equity'], color='blue', label='Stockholders Equity')
ax1.plot(income_statement_t['Net Income'], color='red', label='Net Income')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Equity and Net Income (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the return on equity
ax2 = ax1.twinx()
ax2.plot(return_on_equity, color='green', label='Return on Equity (%)')
ax2.set_ylabel('Return on Equity (%)')
ax2.tick_params(axis='y', colors='green')
plt.title('Stockholders Equity, Net Income, and Return on Equity of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Liquidity Ratios: current ratio, quick ratio, and cash ratio
# Current Ratio = Current Assets / Current Liabilities
current_ratio = balance_sheet_t['Current Assets'] / balance_sheet_t['Current Liabilities']
# Rename the column
current_ratio = current_ratio.rename('Current Ratio')
current_ratio
# Out:
# 2023-12-31    3.232413
# 2022-12-31     2.41693
# 2021-12-31    2.797456
# 2020-12-31    2.495256
# Name: Current Ratio, dtype: object

# %%
# Graph the current assets, current liabilities, and current ratio
plt.figure(figsize=(12, 8))
# Create the first axis for the current assets and current liabilities
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Current Assets'], color='blue', label='Current Assets')
ax1.plot(balance_sheet_t['Current Liabilities'], color='red', label='Current Liabilities')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Assets and Liabilities (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the current ratio
ax2 = ax1.twinx()
ax2.plot(current_ratio, color='green', label='Current Ratio')
ax2.set_ylabel('Current Ratio')
ax2.tick_params(axis='y', colors='green')
plt.title('Current Assets, Current Liabilities, and Current Ratio of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Quick Ratio (Current Assets - Inventory) / Current Liabilities
quick_ratio = (balance_sheet_t['Current Assets'] - balance_sheet_t['Inventory']) / balance_sheet_t['Current Liabilities']
# Rename the column
quick_ratio = quick_ratio.rename('Quick Ratio')
quick_ratio
# Out:
# 2023-12-31    2.428383
# 2022-12-31    1.874087
# 2021-12-31     2.23539
# 2020-12-31    1.958126
# Name: Quick Ratio, dtype: object

# %%
# Graph the current assets, current liabilities, inventory, and quick ratio
plt.figure(figsize=(12, 8))
# Create the first axis for the current assets, current liabilities, and inventory
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Current Assets'], color='blue', label='Current Assets')
ax1.plot(balance_sheet_t['Current Liabilities'], color='red', label='Current Liabilities')
ax1.plot(balance_sheet_t['Inventory'], color='purple', label='Inventory')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Assets, Liabilities, and Inventory (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the quick ratio
ax2 = ax1.twinx()
ax2.plot(quick_ratio, color='green', label='Quick Ratio')
ax2.set_ylabel('Quick Ratio')
ax2.tick_params(axis='y', colors='green')
plt.title('Current Assets, Current Liabilities, Inventory, and Quick Ratio of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Cash Ratio Cash / Current Liabilities
cash_ratio = balance_sheet_t['Cash And Cash Equivalents'] / balance_sheet_t['Current Liabilities']
# Rename the column
cash_ratio = cash_ratio.rename('Cash Ratio')
cash_ratio
# Out:
# 2023-12-31     1.32212
# 2022-12-31    1.032708
# 2021-12-31    1.162986
# 2020-12-31    0.774366
# Name: Cash Ratio, dtype: object

# %%
# Graph the cash and cash equivalents, current liabilities, and cash ratio
plt.figure(figsize=(12, 8))
# Create the first axis for the cash and cash equivalents and current liabilities
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Cash And Cash Equivalents'], color='blue', label='Cash and Cash Equivalents')
ax1.plot(balance_sheet_t['Current Liabilities'], color='red', label='Current Liabilities')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Cash and Liabilities (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the cash ratio
ax2 = ax1.twinx()
ax2.plot(cash_ratio, color='green', label='Cash Ratio')
ax2.set_ylabel('Cash Ratio')
ax2.tick_params(axis='y', colors='green')
plt.title('Cash and Cash Equivalents, Current Liabilities, and Cash Ratio of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Inventory Turnover Cost of Goods Sold / Average Inventory
inventory_turnover = income_statement_t['Cost Of Revenue'] / ((balance_sheet_t['Inventory'] + balance_sheet_t['Inventory']) / 2)
# Rename the column
inventory_turnover = inventory_turnover.rename('Inventory Turnover')
inventory_turnover
# Out:
# 2023-12-31     6.83018
# 2022-12-31    7.249326
# 2021-12-31      6.8703
# 2020-12-31     5.49339
# Name: Inventory Turnover, dtype: object

# %%
# Graph the cost of goods sold, inventory, and inventory turnover
plt.figure(figsize=(12, 8))
# Create the first axis for the cost of goods sold and inventory
ax1 = plt.gca()
ax1.plot(income_statement_t['Cost Of Revenue'], color='blue', label='Cost of Revenue')
ax1.plot(balance_sheet_t['Inventory'], color='red', label='Inventory')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Cost of Revenue and Inventory (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the inventory turnover
ax2 = ax1.twinx()
ax2.plot(inventory_turnover, color='green', label='Inventory Turnover')
ax2.set_ylabel('Inventory Turnover')
ax2.tick_params(axis='y', colors='green')
plt.title('Cost of Revenue, Inventory, and Inventory Turnover of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Receivables Turnover Total Revenue / Average Accounts Receivable
receivables_turnover = income_statement_t['Total Revenue'] / ((balance_sheet_t['Accounts Receivable'] + balance_sheet_t['Accounts Receivable']) / 2)
# Rename the column
receivables_turnover = receivables_turnover.rename('Receivables Turnover')
receivables_turnover
# Out:
# 2023-12-31    8.395389
# 2022-12-31    7.476504
# 2021-12-31    6.210499
# 2020-12-31    5.138222
# Name: Receivables Turnover, dtype: object

# %%
# Graph the total revenue, accounts receivable, and receivables turnover
plt.figure(figsize=(12, 8))
# Create the first axis for the total revenue and accounts receivable
ax1 = plt.gca()
ax1.plot(income_statement_t['Total Revenue'], color='blue', label='Total Revenue')
ax1.plot(balance_sheet_t['Accounts Receivable'], color='red', label='Accounts Receivable')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Revenue and Receivables (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the receivables turnover
ax2 = ax1.twinx()
ax2.plot(receivables_turnover, color='green', label='Receivables Turnover')
ax2.set_ylabel('Receivables Turnover')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Revenue, Accounts Receivable, and Receivables Turnover of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Leverage Ratios
# Debt to Equity Ratio Total Liabilities / Total Equity
debt_to_equity = balance_sheet_t['Total Liabilities Net Minority Interest'] / balance_sheet_t['Stockholders Equity']
# Rename the column
debt_to_equity = debt_to_equity.rename('Debt to Equity Ratio')
debt_to_equity
# Out:
# 2023-12-31    1.461267
# 2022-12-31    2.167243
# 2021-12-31    2.657195
# 2020-12-31    2.633287
# Name: Debt to Equity Ratio, dtype: object

# %%
# Graph the total liabilities, total equity, and debt to equity ratio
plt.figure(figsize=(12, 8))
# Create the first axis for the total liabilities and total equity
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Total Liabilities Net Minority Interest'], color='blue', label='Total Liabilities')
ax1.plot(balance_sheet_t['Stockholders Equity'], color='red', label='Stockholders Equity')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Liabilities and Equity (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the debt to equity ratio
ax2 = ax1.twinx()
ax2.plot(debt_to_equity, color='green', label='Debt to Equity Ratio')
ax2.set_ylabel('Debt to Equity Ratio')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Liabilities, Stockholders Equity, and Debt to Equity Ratio of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Debt to Assets Ratio Total Liabilities / Total Assets
debt_to_assets = balance_sheet_t['Total Liabilities Net Minority Interest'] / balance_sheet_t['Total Assets']
# Rename the column
debt_to_assets = debt_to_assets.rename('Debt to Assets Ratio')
debt_to_assets
# Out:
# 2023-12-31    0.591944
# 2022-12-31    0.681793
# 2021-12-31    0.723336
# 2020-12-31    0.721048
# Name: Debt to Assets Ratio, dtype: object

# %%
# Graph the total liabilities, total assets, and debt to assets ratio
plt.figure(figsize=(12, 8))
# Create the first axis for the total liabilities and total assets
ax1 = plt.gca()
ax1.plot(balance_sheet_t['Total Liabilities Net Minority Interest'], color='blue', label='Total Liabilities')
ax1.plot(balance_sheet_t['Total Assets'], color='red', label='Total Assets')
ax1.set_xlabel('Time (Years, Quarters, etc.)')
ax1.set_ylabel('Liabilities and Assets (Dollars)')
ax1.tick_params(axis='y', colors='black')
# Create the second axis for the debt to assets ratio
ax2 = ax1.twinx()
ax2.plot(debt_to_assets, color='green', label='Debt to Assets Ratio')
ax2.set_ylabel('Debt to Assets Ratio')
ax2.tick_params(axis='y', colors='green')
plt.title('Total Liabilities, Total Assets, and Debt to Assets Ratio of SLCA')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')
plt.show()

# %%
# Interest Coverage Ratio EBIT / Interest Expense
interest_coverage = income_statement_t['EBIT'] / income_statement_t['Interest Expense']
# Rename the column
interest_coverage = interest_coverage.rename('Interest Coverage Ratio')
interest_coverage
# Out:
# 2023-12-31    2.922829
# 2022-12-31    2.340228
# 2021-12-31    0.478955
# 2020-12-31   -1.192489
# Name: Interest Coverage Ratio, dtype: object

# %%
# Dividends
# Does SLCA have a dividend?
yf.Ticker(slca).dividends.tail()
# Out:
# Date
# 2019-03-13 00:00:00-04:00    0.063
# 2019-06-13 00:00:00-04:00    0.063
# 2019-09-12 00:00:00-04:00    0.063
# 2019-12-12 00:00:00-05:00    0.063
# 2020-03-12 00:00:00-04:00    0.020
# Name: Dividends, dtype: float64

# %%
# Price to Earnings Ratio Price / Earnings per Share
price_to_earnings = hist_data['Close'] / yf.Ticker(slca).info['trailingEps']
price_to_earnings.index
# Out:
# DatetimeIndex(['2019-05-01 00:00:00-04:00', '2019-05-02 00:00:00-04:00',
#                '2019-05-03 00:00:00-04:00', '2019-05-06 00:00:00-04:00',
#                '2019-05-07 00:00:00-04:00', '2019-05-08 00:00:00-04:00',
#                '2019-05-09 00:00:00-04:00', '2019-05-10 00:00:00-04:00',
#                '2019-05-13 00:00:00-04:00', '2019-05-14 00:00:00-04:00',
#                ...
#                '2024-04-17 00:00:00-04:00', '2024-04-18 00:00:00-04:00',
#                '2024-04-19 00:00:00-04:00', '2024-04-22 00:00:00-04:00',
#                '2024-04-23 00:00:00-04:00', '2024-04-24 00:00:00-04:00',
#                '2024-04-25 00:00:00-04:00', '2024-04-26 00:00:00-04:00',
#                '2024-04-29 00:00:00-04:00', '2024-04-30 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=1259, freq=None)

# %%
price_to_earnings
# Out:
# Date
# 2019-05-01 00:00:00-04:00     9.631447
# 2019-05-02 00:00:00-04:00     9.048319
# 2019-05-03 00:00:00-04:00     9.526615
# 2019-05-06 00:00:00-04:00     9.454543
# 2019-05-07 00:00:00-04:00     9.166254
#                                ...
# 2024-04-24 00:00:00-04:00     8.741497
# 2024-04-25 00:00:00-04:00     8.884354
# 2024-04-26 00:00:00-04:00    10.809524
# 2024-04-29 00:00:00-04:00    10.585034
# 2024-04-30 00:00:00-04:00    10.496599
# Name: Close, Length: 1259, dtype: float64

# %%
# Find the values '2020-12-31' and '2021-12-31'
dates = ['2020-12-31', '2021-12-31', '2022-12-30', '2023-12-29']
for date in dates:
    print(price_to_earnings.loc[date])
    
# Put only the values from the dates into a dataframe
price_to_earnings = price_to_earnings.loc[dates]
price_to_earnings
# Out:
# 4.775510191106472
# 6.394557563626036
# 8.503401360544219
# 7.693877836473945
# Date
# 2020-12-31 00:00:00-05:00    4.775510
# 2021-12-31 00:00:00-05:00    6.394558
# 2022-12-30 00:00:00-05:00    8.503401
# 2023-12-29 00:00:00-05:00    7.693878
# Name: Close, dtype: float64

# %%
# Price to Book Ratio Price / Book Value per Share
book_value = yf.Ticker(slca).info['bookValue']
price_to_book = hist_data['Close'] / book_value
# Rename the column
price_to_book = price_to_book.rename('Price to Book Ratio')
price_to_book.tail()
# Out:
# Date
# 2024-04-24 00:00:00-04:00    1.161215
# 2024-04-25 00:00:00-04:00    1.180192
# 2024-04-26 00:00:00-04:00    1.435930
# 2024-04-29 00:00:00-04:00    1.406109
# 2024-04-30 00:00:00-04:00    1.394361
# Name: Price to Book Ratio, dtype: float64

# %%
# Find the values for '2020-12-31' and '2021-12-31' or the closest date
dates = ['2020-12-31', '2021-12-31', '2022-12-30', '2023-12-29']
for date in dates:
    print(price_to_book.loc[date])

# Put only the values from the dates into a dataframe
price_to_book = price_to_book.loc[dates]
price_to_book
# Out:
# 0.6343755630694482
# 0.8494487275013801
# 1.1295861196457617
# 1.0220495589749412
# Date
# 2020-12-31 00:00:00-05:00    0.634376
# 2021-12-31 00:00:00-05:00    0.849449
# 2022-12-30 00:00:00-05:00    1.129586
# 2023-12-29 00:00:00-05:00    1.022050
# Name: Price to Book Ratio, dtype: float64

# %%
# Find the total equity from the balance sheet
income_statement_t.columns
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBITDA',
#        'EBIT', 'Net Interest Income', 'Interest Expense', 'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Total Operating Income As Reported',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Net Income', 'Minority Interests',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Other Income Expense', 'Other Non Operating Income Expenses',
# ...

# %%
# Calculate the tax rate
tax_rate = income_statement_t['Tax Provision'] / income_statement_t['Pretax Income'] 
tax_rate
# Out:
# 2023-12-31     0.25096
# 2022-12-31    0.251531
# 2021-12-31    0.074307
# 2020-12-31    0.342712
# dtype: object

# %%
# Convert the date index from tz-naive to tz-aware
for ratio in [gross_profit_margin, operating_margin, net_profit_margin, return_on_assets, return_on_equity, current_ratio, quick_ratio, cash_ratio, inventory_turnover, receivables_turnover, debt_to_equity, debt_to_assets, interest_coverage, price_to_earnings, price_to_book]:
    ratio.index = ratio.index.tz_convert('America/New_York')

# %%
# Put all the ratios into one dataframe
ratios = pd.concat([gross_profit_margin, operating_margin, net_profit_margin, return_on_assets, return_on_equity, current_ratio, quick_ratio, cash_ratio, inventory_turnover, receivables_turnover, debt_to_equity, debt_to_assets, interest_coverage, price_to_earnings, price_to_book], axis=1)

# %%
ratios
# Out:
#                           Gross Profit Margin Operating Margin  \
# 2020-12-31 00:00:00-05:00           32.015581       -11.261815
# 2021-12-31 00:00:00-05:00           27.982777         3.087385
# 2022-12-30 00:00:00-05:00                 NaN              NaN
# 2022-12-31 00:00:00-05:00           29.830436        11.906852
# 2023-12-29 00:00:00-05:00                 NaN              NaN
# 2023-12-31 00:00:00-05:00           34.238883        19.154239
#
#                           Net Profit Margin Return on Assets Return on Equity  \
# 2020-12-31 00:00:00-05:00        -13.488122        -5.077734        -18.54403
# 2021-12-31 00:00:00-05:00         -3.058397         -1.52104        -5.587581
# 2022-12-30 00:00:00-05:00               NaN              NaN              NaN
# 2022-12-31 00:00:00-05:00          5.125801          3.53006         11.22114
# 2023-12-29 00:00:00-05:00               NaN              NaN              NaN
# ...

# %%
# Check for missing values
ratios.isnull().sum()
# Out:
# Gross Profit Margin        2
# Operating Margin           2
# Net Profit Margin          2
# Return on Assets           2
# Return on Equity           2
# Current Ratio              2
# Quick Ratio                2
# Cash Ratio                 2
# Inventory Turnover         2
# Receivables Turnover       2
# Debt to Equity Ratio       2
# Debt to Assets Ratio       2
# Interest Coverage Ratio    2
# Close                      2
# Price to Book Ratio        2
# dtype: int64

# %% [markdown]
# __SLCA's Weighted Average Cost of Capital (WACC)__
# <br>
# $ WACC = \frac{E}{V} \times R_e + \frac{D}{V} \times R_d \times (1 - T_c) $
# <br>
# Where:
# - $ E $ is the market value of equity
# - $ V $ is the total market value of equity and debt
# - $ R_e $ is the cost of equity
# - $ D $ is the market value of debt
# - $ R_d $ is the cost of debt
# - $ T_c $ is the tax rate

# %%
# Calculate the market value of equity
market_value_equity = hist_data['Close'] * yf.Ticker(slca).info['sharesOutstanding']
market_value_equity
# Out:
# Date
# 2019-05-01 00:00:00-04:00    1.106250e+09
# 2019-05-02 00:00:00-04:00    1.039273e+09
# 2019-05-03 00:00:00-04:00    1.094209e+09
# 2019-05-06 00:00:00-04:00    1.085931e+09
# 2019-05-07 00:00:00-04:00    1.052819e+09
#                                  ...
# 2024-04-24 00:00:00-04:00    1.004032e+09
# 2024-04-25 00:00:00-04:00    1.020441e+09
# 2024-04-26 00:00:00-04:00    1.241562e+09
# 2024-04-29 00:00:00-04:00    1.215778e+09
# 2024-04-30 00:00:00-04:00    1.205620e+09
# Name: Close, Length: 1259, dtype: float64

# %%
# Graph the market value of equity
plt.figure(figsize=(12, 8))
plt.plot(market_value_equity, label='Market Value of Equity')
plt.title('Market Value of Equity of SLCA')
# Put the vertical line on April 26, 2024
plt.axvline(pd.Timestamp('2024-04-26'), color='black', linestyle='--', label='Apollo Acquisition Date')
# Put the horizontal line at the mean of the market value of equity
plt.axhline(market_value_equity.mean(), color='red', linestyle='--', label='Mean Market Value of Equity')
# Put the horizontal line at the Apollo Acquisition Price
plt.axhline(15.5 * yf.Ticker(slca).info['sharesOutstanding'], color='green', linestyle='--', label='Apollo Acquisition Price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Project the Projected Revenue, Ebitda, and Net income

# %%
# Save the income statement, balance sheet, and cash flow statements of SLCA and its peers to a csv file
income_statement_t.to_csv('income_statement_t.csv')
balance_sheet_t.to_csv('balance_sheet_t.csv')
cash_flow_t.to_csv('cash_flow_t.csv')

# %%
# Save the names of the peers to a list
peers_names = list(peers.keys())
peers_names
# Out:
# ['RPC Inc',
#  'ProPetro Holding Corp',
#  'Cactus',
#  'Core Laboratories',
#  'ChampionX Corp',
#  'Patterson-UTI Energy',
#  'Liberty Energy Inc.']

# %%
# Get the tickers for the peers
peers_tickers = list(peers.values())
peers_tickers
# Out:
# ['RES', 'PUMP', 'WHD', 'CLB', 'CHX', 'PTEN', 'LBRT']

# %%
for pt in peers_tickers:
# Save the income statement, balance sheet, and cash flow statements of the peers to a csv file
    income_statement_peers[pt].to_csv(f'{pt}_income_statement.csv')
    balance_sheet_peers[pt].to_csv(f'{pt}_balance_sheet.csv')
    cash_flow_peers[pt].to_csv(f'{pt}_cash_flow.csv')
